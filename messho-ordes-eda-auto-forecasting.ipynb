# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/meesho-orders/meesho ForwardReports.csv
# /kaggle/input/meesho-orders/meesho Orders Aug.csv

# %%
data = pd.read_csv("/kaggle/input/meesho-orders/meesho Orders Aug.csv")
data.head()
# Out:
#   Reason for Credit Entry    Sub Order No  Order Date  Customer State  \
# 0               DELIVERED  406826346276_1  2022-08-01       Rajasthan
# 1               CANCELLED  216649987717_1  2022-08-02  Andhra Pradesh
# 2               DELIVERED  184970118893_1  2022-08-02       Karnataka
# 3            RTO_COMPLETE  916538974169_1  2022-08-02           Assam
# 4               DELIVERED  528661643961_1  2022-08-02     West Bengal
#
#                                         Product Name         SKU  \
# 0  FIVESTAR Georgette Lehengha Choli with Inner C...        6326
# 1  Beautiful pure lakhnovi long kurta embroidery ...      Kb 201
# 2   PARTY WEAR BEAUTIFUL LOOK FANCY EMBROIDERY AN...     hk 1446
# 3  FIVESTAR Designer Suit On Havy Gorgette febric...  1101 black
# 4                                       stlish dress    mk -6114
#
#             Size  Quantity  Supplier Listed Price (Incl. GST + Commission)  \
# 0  Semi Stitched         1                                          1910.0
# 1            XXL         1                                          1500.0
# 2      Free Size         1                                          1561.0
# 3  Semi Stitched         1                                          1749.0
# 4             XL         1                                           750.0
#
#    Supplier Discounted Price (Incl GST and Commision)
# 0                                             1910.0
# 1                                             1500.0
# 2                                             1561.0
# 3                                             1749.0
# 4                                              750.0

# %%
data.drop(["Supplier Discounted Price (Incl GST and Commision)"],inplace=True,axis=1)
data.columns = ["status","id","date","state","name","sku","size","quantity","price"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   status    208 non-null    object
#  1   id        208 non-null    object
#  2   date      208 non-null    object
#  3   state     208 non-null    object
#  4   name      208 non-null    object
#  5   sku       208 non-null    object
#  6   size      208 non-null    object
#  7   quantity  208 non-null    int64
#  8   price     208 non-null    float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 14.8+ KB

# %%
plt.pie(data["status"].value_counts(),autopct="%0.2f%%",labels=data["status"].unique(),radius=1)
plt.show()

# %%
plt.figure(figsize=(15,4))
sns.barplot(data=data,x="size",y="price")
# Out:
# <AxesSubplot:xlabel='size', ylabel='price'>

# %% [markdown]
# - Semi Stitched Product Price is High

# %%
sns.barplot(y = data.groupby("status")["price"].sum(),x=data.status.unique())
# Out:
# <AxesSubplot:ylabel='price'>

# %% [markdown]
# - **90K+** Order delivered
# - **140K** worth order has cancelled

# %%
sns.histplot(data["price"])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# - seller sale product **range 250-2300**
# - **most of product range 1200-1500**

# %%
rto = pd.DataFrame(data[data["status"]=="RTO_COMPLETE"])
rto.head()
# Out:
#           status              id        date           state  \
# 3   RTO_COMPLETE  916538974169_1  2022-08-02           Assam
# 5   RTO_COMPLETE  261363877240_1  2022-08-02   Uttar Pradesh
# 9   RTO_COMPLETE  183404359462_1  2022-08-03           Bihar
# 12  RTO_COMPLETE  493966375185_1  2022-08-04          Odisha
# 37  RTO_COMPLETE  545646779706_1  2022-08-08  Andhra Pradesh
#
#                                                  name          sku  \
# 3   FIVESTAR Designer Suit On Havy Gorgette febric...   1101 black
# 5   Heavy faux georgette with embroidery work with...     Ad 009 a
# 9                                    top & bottom set  akshar 1090
# 12   PARTY WEAR LOOK HEAVY EMBROIDERY AND 5mm SEQU...      Hk1408b
# 37   PARTY WEAR LOOK HEAVY EMBROIDERY AND 5mm SEQU...      Hk1408b
#
#              size  quantity   price
# 3   Semi Stitched         1  1749.0
# 5             XXL         1  1500.0
# 9               M         1  1368.0
# 12      Free Size         1  1350.0
# 37      Free Size         1  1350.0

# %%
rto.shape
# Out:
# (28, 9)

# %% [markdown]
# - 28 Product had Return

# %%
plt.figure(figsize=(10,7))
plt.subplot(1,2,1)
plt.pie(rto.groupby("size")["price"].sum(),autopct="%0.2f%%",labels=rto["size"].unique())
plt.subplot(1,2,2)
sns.barplot(y = rto.groupby("size")["price"].sum(),x = rto["size"].unique())
plt.title(" Product Size vs RTO Return")
plt.show()

# %% [markdown]
# > **Which Prodcut has more return?**
# - **Semi Stitch, Free Size** Product Have **high Return**
#
# > **Which product has low return?**
# - XXL size Prodict has Less Retun
#
# **conclusion:-**
# - XXL Prodcut High Demand
# - seller **focus on Semi Stitch & free size** Product quality for increas sale

# %%
deliverd = pd.DataFrame(data[data["status"]=="DELIVERED"])
deliverd
# Out:
#         status              id        date           state  \
# 0    DELIVERED  406826346276_1  2022-08-01       Rajasthan
# 2    DELIVERED  184970118893_1  2022-08-02       Karnataka
# 4    DELIVERED  528661643961_1  2022-08-02     West Bengal
# 10   DELIVERED  322259568161_1  2022-08-03       Telangana
# 11   DELIVERED  173534645547_1  2022-08-04  Madhya Pradesh
# ..         ...             ...         ...             ...
# 196  DELIVERED  910483967612_1  2022-08-30           Assam
# 197  DELIVERED  355129275575_1  2022-08-30           India
# 198  DELIVERED  624159941368_1  2022-08-31          Odisha
# 200  DELIVERED  507323371165_1  2022-08-31       Karnataka
# 206  DELIVERED  653631357267_1  2022-08-31         Haryana
#
#                                                   name       sku  \
# 0    FIVESTAR Georgette Lehengha Choli with Inner C...      6326
# 2     PARTY WEAR BEAUTIFUL LOOK FANCY EMBROIDERY AN...   hk 1446
# 4                                         stlish dress  mk -6114
# 10    PARTY WEAR LOOK HEAVY EMBROIDERY AND 5mm SEQU...   hk 1408
# 11    PARTY WEAR LOOK HEAVY EMBROIDERY AND 5mm SEQU...   hk 1408
# ..                                                 ...       ...
# 196  FIVE STAR Hair Straightener Comb for Women & M...  Uk8ndIGZ
# 197  Fancy look beautiful embroidery work kurti bot...   Hk 1454
# 198  Heavy Soft Butterfly Net With Rose Flower Patt...    Ad 021
# 200  FIVESTAR Bridal Wedding Gorgette Lehengha with...      6320
# 206  FIVESTAR Bridal Wedding Gorgette Lehengha with...      6320
#
#               size  quantity   price
# 0    Semi Stitched         1  1910.0
# 2        Free Size         1  1561.0
# 4               XL         1   750.0
# 10       Free Size         1  1350.0
# 11       Free Size         1  1350.0
# ..             ...       ...     ...
# 196      Free Size         1   429.0
# 197             XL         1  1368.0
# 198            XXL         1  1300.0
# 200  Semi Stitched         1  1949.0
# 206  Semi Stitched         1  1949.0
#
# [111 rows x 9 columns]

# %%
plt.figure(figsize=(15,5))
barplot = sns.barplot(y = deliverd.groupby("size")["price"].sum(),x = deliverd["size"].unique())
plt.title(" Product Size vs Deliverd")
plt.show()

# %% [markdown]
# > which prodcut has highest or lowest sell?
# - **Semi Stitched,** - product has more sell
# - **XXXL Size** Product has lowest sell means **XXXL no demand**

# %%
plt.figure(figsize=(15,5))
barplot = sns.barplot(y = sorted(deliverd.groupby("state")["price"].sum(),reverse=True),x = deliverd["state"].unique())
plt.title("State vs Deliverd Order")
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# > Which state have more order?
# - most of order recived from Rajasthan & karnataka.

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=data["date"].unique() ,y = data["date"].value_counts())
plt.title("Date vs Oreder")
plt.xticks(rotation=70)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=data["date"].unique() ,y = data.groupby("date")["price"].sum())
plt.title("Date vs Oreder")
plt.xticks(rotation=70)
plt.show()

# %%
# Convert Data object to DateTime
# extract day from date

data["date"] = pd.to_datetime(data["date"])
deliverd["date"] = pd.to_datetime(deliverd["date"])
data["day_name"] = data["date"].dt.day_name()
data["day"] = data["date"].dt.day
deliverd["day_name"] = deliverd["date"].dt.day_name()
deliverd["day"] = deliverd["date"].dt.day

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=data["day_name"].unique() ,y = data.groupby("day_name")["price"].sum())
plt.title("Day vs Oreder")
plt.xticks(rotation=70)
plt.show()

# %%
data.head(3)
# Out:
#       status              id       date           state  \
# 0  DELIVERED  406826346276_1 2022-08-01       Rajasthan
# 1  CANCELLED  216649987717_1 2022-08-02  Andhra Pradesh
# 2  DELIVERED  184970118893_1 2022-08-02       Karnataka
#
#                                                 name      sku           size  \
# 0  FIVESTAR Georgette Lehengha Choli with Inner C...     6326  Semi Stitched
# 1  Beautiful pure lakhnovi long kurta embroidery ...   Kb 201            XXL
# 2   PARTY WEAR BEAUTIFUL LOOK FANCY EMBROIDERY AN...  hk 1446      Free Size
#
#    quantity   price day_name  day
# 0         1  1910.0   Monday    1
# 1         1  1500.0  Tuesday    2
# 2         1  1561.0  Tuesday    2

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(data["day"].unique(), data.groupby("day")["price"].sum())
plt.title("Day vs Order Price")
plt.subplot(1,2,2)
plt.plot(data["day"].unique(), data.groupby("day")["price"].count())
plt.title("Day vs Order Count")
# Out:
# Text(0.5, 1.0, 'Day vs Order Count')

# %%
pred_df = data.groupby("date")["price"].count().to_frame()
pred_df.reset_index(inplace=True)
pred_df.columns = ["ds","y"]
pred_df.head(3)
# Out:
#           ds  y
# 0 2022-08-01  1
# 1 2022-08-02  6
# 2 2022-08-03  4

# %% [markdown]
# # **Prophet: Automatic Forecasting Procedure**

# %%
# !pip install pystan==2.19
# !pip install fbprophet
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7dd5cdd3d5d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pystan/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7dd5cdd3df90>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pystan/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7dd5cdd3dcd0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pystan/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7dd5cdd01b90>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pystan/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7dd5cdd01210>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pystan/
# ERROR: Could not find a version that satisfies the requirement pystan==2.19 (from versions: none)
# ERROR: No matching distribution found for pystan==2.19
# WARNING: There was an error checking the latest version of pip.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7956939a9590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/fbprophet/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x795693930890>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/fbprophet/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x795693930990>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/fbprophet/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7956939303d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/fbprophet/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7956939305d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/fbprophet/
# ERROR: Could not find a version that satisfies the requirement fbprophet (from versions: none)
# ERROR: No matching distribution found for fbprophet
# WARNING: There was an error checking the latest version of pip.

# %%
from fbprophet import Prophet
m = Prophet()
m.fit(pred_df)  # df is a pandas.DataFrame with 'y' and 'ds' columns
future = m.make_future_dataframe(periods=10)
predict = m.predict(future)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_17/4231581384.py in <module>
# ----> 1 from fbprophet import Prophet
#       2 m = Prophet()
#       3 m.fit(pred_df)  # df is a pandas.DataFrame with 'y' and 'ds' columns
#       4 future = m.make_future_dataframe(periods=10)
#       5 predict = m.predict(future)
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
fig1 = m.plot(predict)

# %%
plt.figure(figsize=(20,5))
plt.plot(predict["ds"],predict["yhat"],label="Prediced")
plt.plot(pred_df["ds"],pred_df["y"],label="Actual")
plt.title("10 Day order Prediction")
plt.legend()

# %%
fig2 = m.plot_components(predict)
